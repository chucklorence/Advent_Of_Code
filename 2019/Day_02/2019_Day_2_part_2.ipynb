# %%
import numpy as np

###########################################################################################
# Global Variables
###########################################################################################
# Global computer variable
intcode_program = np.array([])
# Keeps track of the number of times we've worked an iteration of the program
iteration_counter = 0
# Indicates our location in the program
position_pointer = 0
# Log file name
log_file_name = "log_file.txt"


###########################################################################################
# Functions
###########################################################################################
# Get the original puzzel inputs
def Get_Computer_Inputs():    
    file_contents = open("puzzel_input.txt","r").read()    
    inputs = [int(num.strip()) for num in file_contents.split(",") ]
    return inputs

# Save state
def Save_State():
    return

# Returns the next 4 values from the intcode program
def Get_Next_4():
    next4 = intcode_program[position_pointer:position_pointer+4]
    return next4
    
#
def Increment_Pointer():
    global position_pointer
    position_pointer = position_pointer + 4
    #print(f"position pointer = {position_pointer}")
    return

#
def Reset_Pointer():
    global position_pointer
    position_pointer = 0
    #print(f"position pointer = {position_pointer}")
    return

#
def Increment_Counter():
    global iteration_counter
    iteration_counter = iteration_counter + 1
    #print(f"iteration_counter = {iteration_counter}")
    return

# Log iteration for debugging purposes 
def Log_Iteration(program_segment):
    file = open(log_file_name,"a")    
    if iteration_counter == 1:
        file.write(f"({iteration_counter}; Segment = [{','.join([str(num) for num in program_segment])}];  pointer: {position_pointer}\n")
    else:
        file.write(f"\n({iteration_counter}; Segment = [{','.join([str(num) for num in program_segment])}];  pointer: {position_pointer}\n")
    
    file.close()
    with open(log_file_name,"a") as file:        
        file.write(','.join([str(num) for num in intcode_program]))
        file.write('\n')
    return

#
def Clear_Log():
    file = open(log_file_name,"w")
    file.write("")
    file.close()
    return

# %%
# For part 2, idea - create a dictionary that pairs every number 0 - 99 with another set of numbers 0 - 99
# Then run the program using those pairs until we get the result we want

# Or...we would simply run the program, incrementing the pairs....

############################################################################
# Determine what pair of inputs produces the output 19690720
# The answer will be noun=X and verb=Y --> nounVerb
# E.g. noun=12 and very=2 = 1202
############################################################################

# Create the Lists of lists where each list contains a pair of numbers we want to use to find the answer
input_pairs = []
for noun in range(0,100):
    for verb in range(0,100):
        input_pairs.append([noun,verb])

# Reset our log file
Clear_Log()

# Store the final pair of numbers
final_input_pair = []

for input_pair in input_pairs:
    
    # Reset the pointer
    Reset_Pointer()

    # Refresh the intcode_program
    intcode_program = Get_Computer_Inputs()

    # Replace values at addresses 1 and 2
    intcode_program[1] = input_pair[0]
    intcode_program[2] = input_pair[1]    

    continue_program = True
    while continue_program == True:

        Increment_Counter()
        next4 = Get_Next_4()

        if next4[0] == 1:
            #print('Addition')   
            loc1 = next4[1]
            loc2 = next4[2]
            locStore = next4[3]
            result = intcode_program[loc1] + intcode_program[loc2]
            intcode_program[locStore] = result
            continue_program = True
        elif next4[0] == 2:
            #print('Multiplication')
            loc1 = next4[1]
            loc2 = next4[2]
            locStore = next4[3]
            result = intcode_program[loc1] * intcode_program[loc2]
            intcode_program[locStore] = result        
            continue_program = True
        elif next4[0] == 99:
            #print('End Program')
            continue_program = False
        else:
            print('An Error has occured')
            continue_program = False
        
        #Log_Iteration(next4)
        if continue_program == True:
            Increment_Pointer()
    
    # Program has completed
    # Check the result at position 0 to determine if we have the result we're looking for
    if intcode_program[0] == 19690720:
        final_input_pair = input_pair
        break
    else:
        print(f"Program halted. Not the value we're looking for: {intcode_program[0]}")

# Check to see if we found the final pair
if len(final_input_pair) == 0:
    print("Pair NOT found.")
else:
    print(f"Program halted. Found it! Value at position 0: {intcode_program[0]}")
    print(f"Noun = {final_input_pair[0]}. Verb = {final_input_pair[1]}")
# Out:
# Program halted. Not the value we're looking for: 250661
# Program halted. Not the value we're looking for: 250662
# Program halted. Not the value we're looking for: 250663
# Program halted. Not the value we're looking for: 250664
# Program halted. Not the value we're looking for: 250665
# Program halted. Not the value we're looking for: 250666
# Program halted. Not the value we're looking for: 250667
# Program halted. Not the value we're looking for: 250668
# Program halted. Not the value we're looking for: 250669
# Program halted. Not the value we're looking for: 250670
# Program halted. Not the value we're looking for: 250671
# Program halted. Not the value we're looking for: 250672
# Program halted. Not the value we're looking for: 250673
# Program halted. Not the value we're looking for: 250674
# Program halted. Not the value we're looking for: 250675
# Program halted. Not the value we're looking for: 250676
# Program halted. Not the value we're looking for: 250677
# Program halted. Not the value we're looking for: 250678
# Program halted. Not the value we're looking for: 250679
# Program halted. Not the value we're looking for: 250680
# Program halted. Not the value we're looking for: 250681
# Program halted. Not the value we're looking for: 250682
# Program halted. Not the value we're looking for: 250683
# Program halted. Not the value we're looking for: 250684
# Program halted. Not the value we're looking for: 250685
# Program halted. Not the value we're looking for: 250686
# Program halted. Not the value we're looking for: 250687
# Program halted. Not the value we're looking for: 250688
# Program halted. Not the value we're looking for: 250689
# Program halted. Not the value we're looking for: 250690
# Program halted. Not the value we're looking for: 250691
# Program halted. Not the value we're looking for: 250692
# Program halted. Not the value we're looking for: 250693
# Program halted. Not the value we're looking for: 250694
# Program halted. Not the value we're looking for: 250695
# Program halted. Not the value we're looking for: 250696
# Program halted. Not the value we're looking for: 250697
# Program halted. Not the value we're looking for: 250698
# Program halted. Not the value we're looking for: 250699
# Program halted. Not the value we're looking for: 250700
# Program halted. Not the value we're looking for: 250701
# Program halted. Not the value we're looking for: 250702
# Program halted. Not the value we're looking for: 250703
# Program halted. Not the value we're looking for: 250704
# Program halted. Not the value we're looking for: 250705
# Program halted. Not the value we're looking for: 250706
# Program halted. Not the value we're looking for: 250707
# Program halted. Not the value we're looking for: 250708
# Program halted. Not the value we're looking for: 250709
# Program halted. Not the value we're looking for: 250710
# Program halted. Not the value we're looking for: 250711
# Program halted. Not the value we're looking for: 250712
# Program halted. Not the value we're looking for: 250713
# Program halted. Not the value we're looking for: 250714
# Program halted. Not the value we're looking for: 250715
# Program halted. Not the value we're looking for: 250716
# Program halted. Not the value we're looking for: 250717
# Program halted. Not the value we're looking for: 250718
# Program halted. Not the value we're looking for: 250719
# Program halted. Not the value we're looking for: 250720
# Program halted. Not the value we're looking for: 250721
# Program halted. Not the value we're looking for: 250722
# Program halted. Not the value we're looking for: 250723
# Program halted. Not the value we're looking for: 250724
# Program halted. Not the value we're looking for: 250725
# Program halted. Not the value we're looking for: 250726
# Program halted. Not the value we're looking for: 250727
# Program halted. Not the value we're looking for: 250728
# Program halted. Not the value we're looking for: 250729
# Program halted. Not the value we're looking for: 250730
# Program halted. Not the value we're looking for: 250731
# Program halted. Not the value we're looking for: 250732
# Program halted. Not the value we're looking for: 250733
# Program halted. Not the value we're looking for: 250734
# Program halted. Not the value we're looking for: 250735
# Program halted. Not the value we're looking for: 250736
# Program halted. Not the value we're looking for: 250737
# Program halted. Not the value we're looking for: 250738
# Program halted. Not the value we're looking for: 250739
# Program halted. Not the value we're looking for: 250740
# Program halted. Not the value we're looking for: 250741
# Program halted. Not the value we're looking for: 250742
# Program halted. Not the value we're looking for: 250743
# Program halted. Not the value we're looking for: 250744
# Program halted. Not the value we're looking for: 250745
# Program halted. Not the value we're looking for: 250746
# Program halted. Not the value we're looking for: 250747
# Program halted. Not the value we're looking for: 250748
# Program halted. Not the value we're looking for: 250749
# Program halted. Not the value we're looking for: 250750
# Program halted. Not the value we're looking for: 250751
# Program halted. Not the value we're looking for: 250752
# Program halted. Not the value we're looking for: 250753
# Program halted. Not the value we're looking for: 250754
# Program halted. Not the value we're looking for: 250755
# Program halted. Not the value we're looking for: 250756
# Program halted. Not the value we're looking for: 250757
# Program halted. Not the value we're looking for: 250758
# Program halted. Not the value we're looking for: 250759
# Program halted. Not the value we're looking for: 250760
# Program halted. Not the value we're looking for: 682661
# Program halted. Not the value we're looking for: 682662
# Program halted. Not the value we're looking for: 682663
# Program halted. Not the value we're looking for: 682664
# Program halted. Not the value we're looking for: 682665
# Program halted. Not the value we're looking for: 682666
# Program halted. Not the value we're looking for: 682667
# Program halted. Not the value we're looking for: 682668
# Program halted. Not the value we're looking for: 682669
# Program halted. Not the value we're looking for: 682670
# Program halted. Not the value we're looking for: 682671
# Program halted. Not the value we're looking for: 682672
# Program halted. Not the value we're looking for: 682673
# Program halted. Not the value we're looking for: 682674
# Program halted. Not the value we're looking for: 682675
# Program halted. Not the value we're looking for: 682676
# Program halted. Not the value we're looking for: 682677
# Program halted. Not the value we're looking for: 682678
# Program halted. Not the value we're looking for: 682679
# Program halted. Not the value we're looking for: 682680
# Program halted. Not the value we're looking for: 682681
# Program halted. Not the value we're looking for: 682682
# Program halted. Not the value we're looking for: 682683
# Program halted. Not the value we're looking for: 682684
# Program halted. Not the value we're looking for: 682685
# Program halted. Not the value we're looking for: 682686
# Program halted. Not the value we're looking for: 682687
# Program halted. Not the value we're looking for: 682688
# Program halted. Not the value we're looking for: 682689
# Program halted. Not the value we're looking for: 682690
# Program halted. Not the value we're looking for: 682691
# Program halted. Not the value we're looking for: 682692
# Program halted. Not the value we're looking for: 682693
# Program halted. Not the value we're looking for: 682694
# Program halted. Not the value we're looking for: 682695
# Program halted. Not the value we're looking for: 682696
# Program halted. Not the value we're looking for: 682697
# Program halted. Not the value we're looking for: 682698
# Program halted. Not the value we're looking for: 682699
# Program halted. Not the value we're looking for: 682700
# Program halted. Not the value we're looking for: 682701
# Program halted. Not the value we're looking for: 682702
# Program halted. Not the value we're looking for: 682703
# Program halted. Not the value we're looking for: 682704
# Program halted. Not the value we're looking for: 682705
# Program halted. Not the value we're looking for: 682706
# Program halted. Not the value we're looking for: 682707
# Program halted. Not the value we're looking for: 682708
# Program halted. Not the value we're looking for: 682709
# Program halted. Not the value we're looking for: 682710
# Program halted. Not the value we're looking for: 682711
# Program halted. Not the value we're looking for: 682712
# Program halted. Not the value we're looking for: 682713
# Program halted. Not the value we're looking for: 682714
# Program halted. Not the value we're looking for: 682715
# Program halted. Not the value we're looking for: 682716
# Program halted. Not the value we're looking for: 682717
# Program halted. Not the value we're looking for: 682718
# Program halted. Not the value we're looking for: 682719
# Program halted. Not the value we're looking for: 682720
# Program halted. Not the value we're looking for: 682721
# Program halted. Not the value we're looking for: 682722
# Program halted. Not the value we're looking for: 682723
# Program halted. Not the value we're looking for: 682724
# Program halted. Not the value we're looking for: 682725
# Program halted. Not the value we're looking for: 682726
# Program halted. Not the value we're looking for: 682727
# Program halted. Not the value we're looking for: 682728
# Program halted. Not the value we're looking for: 682729
# Program halted. Not the value we're looking for: 682730
# Program halted. Not the value we're looking for: 682731
# Program halted. Not the value we're looking for: 682732
# Program halted. Not the value we're looking for: 682733
# Program halted. Not the value we're looking for: 682734
# Program halted. Not the value we're looking for: 682735
# Program halted. Not the value we're looking for: 682736
# Program halted. Not the value we're looking for: 682737
# Program halted. Not the value we're looking for: 682738
# Program halted. Not the value we're looking for: 682739
# Program halted. Not the value we're looking for: 682740
# Program halted. Not the value we're looking for: 682741
# Program halted. Not the value we're looking for: 682742
# Program halted. Not the value we're looking for: 682743
# Program halted. Not the value we're looking for: 682744
# Program halted. Not the value we're looking for: 682745
# Program halted. Not the value we're looking for: 682746
# Program halted. Not the value we're looking for: 682747
# Program halted. Not the value we're looking for: 682748
# Program halted. Not the value we're looking for: 682749
# Program halted. Not the value we're looking for: 682750
# Program halted. Not the value we're looking for: 682751
# Program halted. Not the value we're looking for: 682752
# Program halted. Not the value we're looking for: 682753
# Program halted. Not the value we're looking for: 682754
# Program halted. Not the value we're looking for: 682755
# Program halted. Not the value we're looking for: 682756
# Program halted. Not the value we're looking for: 682757
# Program halted. Not the value we're looking for: 682758
# Program halted. Not the value we're looking for: 682759
# Program halted. Not the value we're looking for: 682760
# Program halted. Not the value we're looking for: 1114661
# Program halted. Not the value we're looking for: 1114662
# Program halted. Not the value we're looking for: 1114663
# Program halted. Not the value we're looking for: 1114664
# Program halted. Not the value we're looking for: 1114665
# Program halted. Not the value we're looking for: 1114666
# Program halted. Not the value we're looking for: 1114667
# Program halted. Not the value we're looking for: 1114668
# Program halted. Not the value we're looking for: 1114669
# Program halted. Not the value we're looking for: 1114670
# Program halted. Not the value we're looking for: 1114671
# Program halted. Not the value we're looking for: 1114672
# Program halted. Not the value we're looking for: 1114673
# Program halted. Not the value we're looking for: 1114674
# Program halted. Not the value we're looking for: 1114675
# Program halted. Not the value we're looking for: 1114676
# Program halted. Not the value we're looking for: 1114677
# Program halted. Not the value we're looking for: 1114678
# Program halted. Not the value we're looking for: 1114679
# Program halted. Not the value we're looking for: 1114680
# Program halted. Not the value we're looking for: 1114681
# Program halted. Not the value we're looking for: 1114682
# Program halted. Not the value we're looking for: 1114683
# Program halted. Not the value we're looking for: 1114684
# Program halted. Not the value we're looking for: 1114685
# Program halted. Not the value we're looking for: 1114686
# Program halted. Not the value we're looking for: 1114687
# Program halted. Not the value we're looking for: 1114688
# Program halted. Not the value we're looking for: 1114689
# Program halted. Not the value we're looking for: 1114690
# Program halted. Not the value we're looking for: 1114691
# Program halted. Not the value we're looking for: 1114692
# Program halted. Not the value we're looking for: 1114693
# Program halted. Not the value we're looking for: 1114694
# Program halted. Not the value we're looking for: 1114695
# Program halted. Not the value we're looking for: 1114696
# Program halted. Not the value we're looking for: 1114697
# Program halted. Not the value we're looking for: 1114698
# Program halted. Not the value we're looking for: 1114699
# Program halted. Not the value we're looking for: 1114700
# Program halted. Not the value we're looking for: 1114701
# Program halted. Not the value we're looking for: 1114702
# Program halted. Not the value we're looking for: 1114703
# Program halted. Not the value we're looking for: 1114704
# Program halted. Not the value we're looking for: 1114705
# Program halted. Not the value we're looking for: 1114706
# Program halted. Not the value we're looking for: 1114707
# Program halted. Not the value we're looking for: 1114708
# Program halted. Not the value we're looking for: 1114709
# Program halted. Not the value we're looking for: 1114710
# Program halted. Not the value we're looking for: 1114711
# Program halted. Not the value we're looking for: 1114712
# Program halted. Not the value we're looking for: 1114713
# Program halted. Not the value we're looking for: 1114714
# Program halted. Not the value we're looking for: 1114715
# Program halted. Not the value we're looking for: 1114716
# Program halted. Not the value we're looking for: 1114717
# Program halted. Not the value we're looking for: 1114718
# Program halted. Not the value we're looking for: 1114719
# Program halted. Not the value we're looking for: 1114720
# Program halted. Not the value we're looking for: 1114721
# Program halted. Not the value we're looking for: 1114722
# Program halted. Not the value we're looking for: 1114723
# Program halted. Not the value we're looking for: 1114724
# Program halted. Not the value we're looking for: 1114725
# Program halted. Not the value we're looking for: 1114726
# Program halted. Not the value we're looking for: 1114727
# Program halted. Not the value we're looking for: 1114728
# Program halted. Not the value we're looking for: 1114729
# Program halted. Not the value we're looking for: 1114730
# Program halted. Not the value we're looking for: 1114731
# Program halted. Not the value we're looking for: 1114732
# Program halted. Not the value we're looking for: 1114733
# Program halted. Not the value we're looking for: 1114734
# Program halted. Not the value we're looking for: 1114735
# Program halted. Not the value we're looking for: 1114736
# Program halted. Not the value we're looking for: 1114737
# Program halted. Not the value we're looking for: 1114738
# Program halted. Not the value we're looking for: 1114739
# Program halted. Not the value we're looking for: 1114740
# Program halted. Not the value we're looking for: 1114741
# Program halted. Not the value we're looking for: 1114742
# Program halted. Not the value we're looking for: 1114743
# Program halted. Not the value we're looking for: 1114744
# Program halted. Not the value we're looking for: 1114745
# Program halted. Not the value we're looking for: 1114746
# Program halted. Not the value we're looking for: 1114747
# Program halted. Not the value we're looking for: 1114748
# Program halted. Not the value we're looking for: 1114749
# Program halted. Not the value we're looking for: 1114750
# Program halted. Not the value we're looking for: 1114751
# Program halted. Not the value we're looking for: 1114752
# Program halted. Not the value we're looking for: 1114753
# Program halted. Not the value we're looking for: 1114754
# Program halted. Not the value we're looking for: 1114755
# Program halted. Not the value we're looking for: 1114756
# Program halted. Not the value we're looking for: 1114757
# Program halted. Not the value we're looking for: 1114758
# Program halted. Not the value we're looking for: 1114759
# Program halted. Not the value we're looking for: 1114760
# Program halted. Not the value we're looking for: 1546661
# Program halted. Not the value we're looking for: 1546662
# Program halted. Not the value we're looking for: 1546663
# Program halted. Not the value we're looking for: 1546664
# Program halted. Not the value we're looking for: 1546665
# Program halted. Not the value we're looking for: 1546666
# Program halted. Not the value we're looking for: 1546667
# Program halted. Not the value we're looking for: 1546668
# Program halted. Not the value we're looking for: 1546669
# Program halted. Not the value we're looking for: 1546670
# Program halted. Not the value we're looking for: 1546671
# Program halted. Not the value we're looking for: 1546672
# Program halted. Not the value we're looking for: 1546673
# Program halted. Not the value we're looking for: 1546674
# Program halted. Not the value we're looking for: 1546675
# Program halted. Not the value we're looking for: 1546676
# Program halted. Not the value we're looking for: 1546677
# Program halted. Not the value we're looking for: 1546678
# Program halted. Not the value we're looking for: 1546679
# Program halted. Not the value we're looking for: 1546680
# Program halted. Not the value we're looking for: 1546681
# Program halted. Not the value we're looking for: 1546682
# Program halted. Not the value we're looking for: 1546683
# Program halted. Not the value we're looking for: 1546684
# Program halted. Not the value we're looking for: 1546685
# Program halted. Not the value we're looking for: 1546686
# Program halted. Not the value we're looking for: 1546687
# Program halted. Not the value we're looking for: 1546688
# Program halted. Not the value we're looking for: 1546689
# Program halted. Not the value we're looking for: 1546690
# Program halted. Not the value we're looking for: 1546691
# Program halted. Not the value we're looking for: 1546692
# Program halted. Not the value we're looking for: 1546693
# Program halted. Not the value we're looking for: 1546694
# Program halted. Not the value we're looking for: 1546695
# Program halted. Not the value we're looking for: 1546696
# Program halted. Not the value we're looking for: 1546697
# Program halted. Not the value we're looking for: 1546698
# Program halted. Not the value we're looking for: 1546699
# Program halted. Not the value we're looking for: 1546700
# Program halted. Not the value we're looking for: 1546701
# Program halted. Not the value we're looking for: 1546702
# Program halted. Not the value we're looking for: 1546703
# Program halted. Not the value we're looking for: 1546704
# Program halted. Not the value we're looking for: 1546705
# Program halted. Not the value we're looking for: 1546706
# Program halted. Not the value we're looking for: 1546707
# Program halted. Not the value we're looking for: 1546708
# Program halted. Not the value we're looking for: 1546709
# Program halted. Not the value we're looking for: 1546710
# Program halted. Not the value we're looking for: 1546711
# Program halted. Not the value we're looking for: 1546712
# Program halted. Not the value we're looking for: 1546713
# Program halted. Not the value we're looking for: 1546714
# Program halted. Not the value we're looking for: 1546715
# Program halted. Not the value we're looking for: 1546716
# Program halted. Not the value we're looking for: 1546717
# Program halted. Not the value we're looking for: 1546718
# Program halted. Not the value we're looking for: 1546719
# Program halted. Not the value we're looking for: 1546720
# Program halted. Not the value we're looking for: 1546721
# Program halted. Not the value we're looking for: 1546722
# Program halted. Not the value we're looking for: 1546723
# Program halted. Not the value we're looking for: 1546724
# Program halted. Not the value we're looking for: 1546725
# Program halted. Not the value we're looking for: 1546726
# Program halted. Not the value we're looking for: 1546727
# Program halted. Not the value we're looking for: 1546728
# Program halted. Not the value we're looking for: 1546729
# Program halted. Not the value we're looking for: 1546730
# Program halted. Not the value we're looking for: 1546731
# Program halted. Not the value we're looking for: 1546732
# Program halted. Not the value we're looking for: 1546733
# Program halted. Not the value we're looking for: 1546734
# Program halted. Not the value we're looking for: 1546735
# Program halted. Not the value we're looking for: 1546736
# Program halted. Not the value we're looking for: 1546737
# Program halted. Not the value we're looking for: 1546738
# Program halted. Not the value we're looking for: 1546739
# Program halted. Not the value we're looking for: 1546740
# Program halted. Not the value we're looking for: 1546741
# Program halted. Not the value we're looking for: 1546742
# Program halted. Not the value we're looking for: 1546743
# Program halted. Not the value we're looking for: 1546744
# Program halted. Not the value we're looking for: 1546745
# Program halted. Not the value we're looking for: 1546746
# Program halted. Not the value we're looking for: 1546747
# Program halted. Not the value we're looking for: 1546748
# Program halted. Not the value we're looking for: 1546749
# Program halted. Not the value we're looking for: 1546750
# Program halted. Not the value we're looking for: 1546751
# Program halted. Not the value we're looking for: 1546752
# Program halted. Not the value we're looking for: 1546753
# Program halted. Not the value we're looking for: 1546754
# Program halted. Not the value we're looking for: 1546755
# Program halted. Not the value we're looking for: 1546756
# Program halted. Not the value we're looking for: 1546757
# Program halted. Not the value we're looking for: 1546758
# Program halted. Not the value we're looking for: 1546759
# Program halted. Not the value we're looking for: 1546760
# Program halted. Not the value we're looking for: 1978661
# Program halted. Not the value we're looking for: 1978662
# Program halted. Not the value we're looking for: 1978663
# Program halted. Not the value we're looking for: 1978664
# Program halted. Not the value we're looking for: 1978665
# Program halted. Not the value we're looking for: 1978666
# Program halted. Not the value we're looking for: 1978667
# Program halted. Not the value we're looking for: 1978668
# Program halted. Not the value we're looking for: 1978669
# Program halted. Not the value we're looking for: 1978670
# Program halted. Not the value we're looking for: 1978671
# Program halted. Not the value we're looking for: 1978672
# Program halted. Not the value we're looking for: 1978673
# Program halted. Not the value we're looking for: 1978674
# Program halted. Not the value we're looking for: 1978675
# Program halted. Not the value we're looking for: 1978676
# Program halted. Not the value we're looking for: 1978677
# Program halted. Not the value we're looking for: 1978678
# Program halted. Not the value we're looking for: 1978679
# Program halted. Not the value we're looking for: 1978680
# Program halted. Not the value we're looking for: 1978681
# Program halted. Not the value we're looking for: 1978682
# Program halted. Not the value we're looking for: 1978683
# Program halted. Not the value we're looking for: 1978684
# Program halted. Not the value we're looking for: 1978685
# Program halted. Not the value we're looking for: 1978686
# Program halted. Not the value we're looking for: 1978687
# Program halted. Not the value we're looking for: 1978688
# Program halted. Not the value we're looking for: 1978689
# Program halted. Not the value we're looking for: 1978690
# Program halted. Not the value we're looking for: 1978691
# Program halted. Not the value we're looking for: 1978692
# Program halted. Not the value we're looking for: 1978693
# Program halted. Not the value we're looking for: 1978694
# Program halted. Not the value we're looking for: 1978695
# Program halted. Not the value we're looking for: 1978696
# Program halted. Not the value we're looking for: 1978697
# Program halted. Not the value we're looking for: 1978698
# Program halted. Not the value we're looking for: 1978699
# Program halted. Not the value we're looking for: 1978700
# Program halted. Not the value we're looking for: 1978701
# Program halted. Not the value we're looking for: 1978702
# Program halted. Not the value we're looking for: 1978703
# Program halted. Not the value we're looking for: 1978704
# Program halted. Not the value we're looking for: 1978705
# Program halted. Not the value we're looking for: 1978706
# Program halted. Not the value we're looking for: 1978707
# Program halted. Not the value we're looking for: 1978708
# Program halted. Not the value we're looking for: 1978709
# Program halted. Not the value we're looking for: 1978710
# Program halted. Not the value we're looking for: 1978711
# Program halted. Not the value we're looking for: 1978712
# Program halted. Not the value we're looking for: 1978713
# Program halted. Not the value we're looking for: 1978714
# Program halted. Not the value we're looking for: 1978715
# Program halted. Not the value we're looking for: 1978716
# Program halted. Not the value we're looking for: 1978717
# Program halted. Not the value we're looking for: 1978718
# Program halted. Not the value we're looking for: 1978719
# Program halted. Not the value we're looking for: 1978720
# Program halted. Not the value we're looking for: 1978721
# Program halted. Not the value we're looking for: 1978722
# Program halted. Not the value we're looking for: 1978723
# Program halted. Not the value we're looking for: 1978724
# Program halted. Not the value we're looking for: 1978725
# Program halted. Not the value we're looking for: 1978726
# Program halted. Not the value we're looking for: 1978727
# Program halted. Not the value we're looking for: 1978728
# Program halted. Not the value we're looking for: 1978729
# Program halted. Not the value we're looking for: 1978730
# Program halted. Not the value we're looking for: 1978731
# Program halted. Not the value we're looking for: 1978732
# Program halted. Not the value we're looking for: 1978733
# Program halted. Not the value we're looking for: 1978734
# Program halted. Not the value we're looking for: 1978735
# Program halted. Not the value we're looking for: 1978736
# Program halted. Not the value we're looking for: 1978737
# Program halted. Not the value we're looking for: 1978738
# Program halted. Not the value we're looking for: 1978739
# Program halted. Not the value we're looking for: 1978740
# Program halted. Not the value we're looking for: 1978741
# Program halted. Not the value we're looking for: 1978742
# Program halted. Not the value we're looking for: 1978743
# Program halted. Not the value we're looking for: 1978744
# Program halted. Not the value we're looking for: 1978745
# Program halted. Not the value we're looking for: 1978746
# Program halted. Not the value we're looking for: 1978747
# Program halted. Not the value we're looking for: 1978748
# Program halted. Not the value we're looking for: 1978749
# Program halted. Not the value we're looking for: 1978750
# Program halted. Not the value we're looking for: 1978751
# Program halted. Not the value we're looking for: 1978752
# Program halted. Not the value we're looking for: 1978753
# Program halted. Not the value we're looking for: 1978754
# Program halted. Not the value we're looking for: 1978755
# Program halted. Not the value we're looking for: 1978756
# Program halted. Not the value we're looking for: 1978757
# Program halted. Not the value we're looking for: 1978758
# Program halted. Not the value we're looking for: 1978759
# Program halted. Not the value we're looking for: 1978760
# Program halted. Not the value we're looking for: 2410661
# Program halted. Not the value we're looking for: 2410662
# Program halted. Not the value we're looking for: 2410663
# Program halted. Not the value we're looking for: 2410664
# Program halted. Not the value we're looking for: 2410665
# Program halted. Not the value we're looking for: 2410666
# Program halted. Not the value we're looking for: 2410667
# Program halted. Not the value we're looking for: 2410668
# Program halted. Not the value we're looking for: 2410669
# Program halted. Not the value we're looking for: 2410670
# Program halted. Not the value we're looking for: 2410671
# Program halted. Not the value we're looking for: 2410672
# Program halted. Not the value we're looking for: 2410673
# Program halted. Not the value we're looking for: 2410674
# Program halted. Not the value we're looking for: 2410675
# Program halted. Not the value we're looking for: 2410676
# Program halted. Not the value we're looking for: 2410677
# Program halted. Not the value we're looking for: 2410678
# Program halted. Not the value we're looking for: 2410679
# Program halted. Not the value we're looking for: 2410680
# Program halted. Not the value we're looking for: 2410681
# Program halted. Not the value we're looking for: 2410682
# Program halted. Not the value we're looking for: 2410683
# Program halted. Not the value we're looking for: 2410684
# Program halted. Not the value we're looking for: 2410685
# Program halted. Not the value we're looking for: 2410686
# Program halted. Not the value we're looking for: 2410687
# Program halted. Not the value we're looking for: 2410688
# Program halted. Not the value we're looking for: 2410689
# Program halted. Not the value we're looking for: 2410690
# Program halted. Not the value we're looking for: 2410691
# Program halted. Not the value we're looking for: 2410692
# Program halted. Not the value we're looking for: 2410693
# Program halted. Not the value we're looking for: 2410694
# Program halted. Not the value we're looking for: 2410695
# Program halted. Not the value we're looking for: 2410696
# Program halted. Not the value we're looking for: 2410697
# Program halted. Not the value we're looking for: 2410698
# Program halted. Not the value we're looking for: 2410699
# Program halted. Not the value we're looking for: 2410700
# Program halted. Not the value we're looking for: 2410701
# Program halted. Not the value we're looking for: 2410702
# Program halted. Not the value we're looking for: 2410703
# Program halted. Not the value we're looking for: 2410704
# Program halted. Not the value we're looking for: 2410705
# Program halted. Not the value we're looking for: 2410706
# Program halted. Not the value we're looking for: 2410707
# Program halted. Not the value we're looking for: 2410708
# Program halted. Not the value we're looking for: 2410709
# Program halted. Not the value we're looking for: 2410710
# Program halted. Not the value we're looking for: 2410711
# Program halted. Not the value we're looking for: 2410712
# Program halted. Not the value we're looking for: 2410713
# Program halted. Not the value we're looking for: 2410714
# Program halted. Not the value we're looking for: 2410715
# Program halted. Not the value we're looking for: 2410716
# Program halted. Not the value we're looking for: 2410717
# Program halted. Not the value we're looking for: 2410718
# Program halted. Not the value we're looking for: 2410719
# Program halted. Not the value we're looking for: 2410720
# Program halted. Not the value we're looking for: 2410721
# Program halted. Not the value we're looking for: 2410722
# Program halted. Not the value we're looking for: 2410723
# Program halted. Not the value we're looking for: 2410724
# Program halted. Not the value we're looking for: 2410725
# Program halted. Not the value we're looking for: 2410726
# Program halted. Not the value we're looking for: 2410727
# Program halted. Not the value we're looking for: 2410728
# Program halted. Not the value we're looking for: 2410729
# Program halted. Not the value we're looking for: 2410730
# Program halted. Not the value we're looking for: 2410731
# Program halted. Not the value we're looking for: 2410732
# Program halted. Not the value we're looking for: 2410733
# Program halted. Not the value we're looking for: 2410734
# Program halted. Not the value we're looking for: 2410735
# Program halted. Not the value we're looking for: 2410736
# Program halted. Not the value we're looking for: 2410737
# Program halted. Not the value we're looking for: 2410738
# Program halted. Not the value we're looking for: 2410739
# Program halted. Not the value we're looking for: 2410740
# Program halted. Not the value we're looking for: 2410741
# Program halted. Not the value we're looking for: 2410742
# Program halted. Not the value we're looking for: 2410743
# Program halted. Not the value we're looking for: 2410744
# Program halted. Not the value we're looking for: 2410745
# Program halted. Not the value we're looking for: 2410746
# Program halted. Not the value we're looking for: 2410747
# Program halted. Not the value we're looking for: 2410748
# Program halted. Not the value we're looking for: 2410749
# Program halted. Not the value we're looking for: 2410750
# Program halted. Not the value we're looking for: 2410751
# Program halted. Not the value we're looking for: 2410752
# Program halted. Not the value we're looking for: 2410753
# Program halted. Not the value we're looking for: 2410754
# Program halted. Not the value we're looking for: 2410755
# Program halted. Not the value we're looking for: 2410756
# Program halted. Not the value we're looking for: 2410757
# Program halted. Not the value we're looking for: 2410758
# Program halted. Not the value we're looking for: 2410759
# Program halted. Not the value we're looking for: 2410760
# Program halted. Not the value we're looking for: 2842661
# Program halted. Not the value we're looking for: 2842662
# Program halted. Not the value we're looking for: 2842663
# Program halted. Not the value we're looking for: 2842664
# Program halted. Not the value we're looking for: 2842665
# Program halted. Not the value we're looking for: 2842666
# Program halted. Not the value we're looking for: 2842667
# Program halted. Not the value we're looking for: 2842668
# Program halted. Not the value we're looking for: 2842669
# Program halted. Not the value we're looking for: 2842670
# Program halted. Not the value we're looking for: 2842671
# Program halted. Not the value we're looking for: 2842672
# Program halted. Not the value we're looking for: 2842673
# Program halted. Not the value we're looking for: 2842674
# Program halted. Not the value we're looking for: 2842675
# Program halted. Not the value we're looking for: 2842676
# Program halted. Not the value we're looking for: 2842677
# Program halted. Not the value we're looking for: 2842678
# Program halted. Not the value we're looking for: 2842679
# Program halted. Not the value we're looking for: 2842680
# Program halted. Not the value we're looking for: 2842681
# Program halted. Not the value we're looking for: 2842682
# Program halted. Not the value we're looking for: 2842683
# Program halted. Not the value we're looking for: 2842684
# Program halted. Not the value we're looking for: 2842685
# Program halted. Not the value we're looking for: 2842686
# Program halted. Not the value we're looking for: 2842687
# Program halted. Not the value we're looking for: 2842688
# Program halted. Not the value we're looking for: 2842689
# Program halted. Not the value we're looking for: 2842690
# Program halted. Not the value we're looking for: 2842691
# Program halted. Not the value we're looking for: 2842692
# Program halted. Not the value we're looking for: 2842693
# Program halted. Not the value we're looking for: 2842694
# Program halted. Not the value we're looking for: 2842695
# Program halted. Not the value we're looking for: 2842696
# Program halted. Not the value we're looking for: 2842697
# Program halted. Not the value we're looking for: 2842698
# Program halted. Not the value we're looking for: 2842699
# Program halted. Not the value we're looking for: 2842700
# Program halted. Not the value we're looking for: 2842701
# Program halted. Not the value we're looking for: 2842702
# Program halted. Not the value we're looking for: 2842703
# Program halted. Not the value we're looking for: 2842704
# Program halted. Not the value we're looking for: 2842705
# Program halted. Not the value we're looking for: 2842706
# Program halted. Not the value we're looking for: 2842707
# Program halted. Not the value we're looking for: 2842708
# Program halted. Not the value we're looking for: 2842709
# Program halted. Not the value we're looking for: 2842710
# Program halted. Not the value we're looking for: 2842711
# Program halted. Not the value we're looking for: 2842712
# Program halted. Not the value we're looking for: 2842713
# Program halted. Not the value we're looking for: 2842714
# Program halted. Not the value we're looking for: 2842715
# Program halted. Not the value we're looking for: 2842716
# Program halted. Not the value we're looking for: 2842717
# Program halted. Not the value we're looking for: 2842718
# Program halted. Not the value we're looking for: 2842719
# Program halted. Not the value we're looking for: 2842720
# Program halted. Not the value we're looking for: 2842721
# Program halted. Not the value we're looking for: 2842722
# Program halted. Not the value we're looking for: 2842723
# Program halted. Not the value we're looking for: 2842724
# Program halted. Not the value we're looking for: 2842725
# Program halted. Not the value we're looking for: 2842726
# Program halted. Not the value we're looking for: 2842727
# Program halted. Not the value we're looking for: 2842728
# Program halted. Not the value we're looking for: 2842729
# Program halted. Not the value we're looking for: 2842730
# Program halted. Not the value we're looking for: 2842731
# Program halted. Not the value we're looking for: 2842732
# Program halted. Not the value we're looking for: 2842733
# Program halted. Not the value we're looking for: 2842734
# Program halted. Not the value we're looking for: 2842735
# Program halted. Not the value we're looking for: 2842736
# Program halted. Not the value we're looking for: 2842737
# Program halted. Not the value we're looking for: 2842738
# Program halted. Not the value we're looking for: 2842739
# Program halted. Not the value we're looking for: 2842740
# Program halted. Not the value we're looking for: 2842741
# Program halted. Not the value we're looking for: 2842742
# Program halted. Not the value we're looking for: 2842743
# Program halted. Not the value we're looking for: 2842744
# Program halted. Not the value we're looking for: 2842745
# Program halted. Not the value we're looking for: 2842746
# Program halted. Not the value we're looking for: 2842747
# Program halted. Not the value we're looking for: 2842748
# Program halted. Not the value we're looking for: 2842749
# Program halted. Not the value we're looking for: 2842750
# Program halted. Not the value we're looking for: 2842751
# Program halted. Not the value we're looking for: 2842752
# Program halted. Not the value we're looking for: 2842753
# Program halted. Not the value we're looking for: 2842754
# Program halted. Not the value we're looking for: 2842755
# Program halted. Not the value we're looking for: 2842756
# Program halted. Not the value we're looking for: 2842757
# Program halted. Not the value we're looking for: 2842758
# Program halted. Not the value we're looking for: 2842759
# Program halted. Not the value we're looking for: 2842760
# Program halted. Not the value we're looking for: 3274661
# Program halted. Not the value we're looking for: 3274662
# Program halted. Not the value we're looking for: 3274663
# Program halted. Not the value we're looking for: 3274664
# Program halted. Not the value we're looking for: 3274665
# Program halted. Not the value we're looking for: 3274666
# Program halted. Not the value we're looking for: 3274667
# Program halted. Not the value we're looking for: 3274668
# Program halted. Not the value we're looking for: 3274669
# Program halted. Not the value we're looking for: 3274670
# Program halted. Not the value we're looking for: 3274671
# Program halted. Not the value we're looking for: 3274672
# Program halted. Not the value we're looking for: 3274673
# Program halted. Not the value we're looking for: 3274674
# Program halted. Not the value we're looking for: 3274675
# Program halted. Not the value we're looking for: 3274676
# Program halted. Not the value we're looking for: 3274677
# Program halted. Not the value we're looking for: 3274678
# Program halted. Not the value we're looking for: 3274679
# Program halted. Not the value we're looking for: 3274680
# Program halted. Not the value we're looking for: 3274681
# Program halted. Not the value we're looking for: 3274682
# Program halted. Not the value we're looking for: 3274683
# Program halted. Not the value we're looking for: 3274684
# Program halted. Not the value we're looking for: 3274685
# Program halted. Not the value we're looking for: 3274686
# Program halted. Not the value we're looking for: 3274687
# Program halted. Not the value we're looking for: 3274688
# Program halted. Not the value we're looking for: 3274689
# Program halted. Not the value we're looking for: 3274690
# Program halted. Not the value we're looking for: 3274691
# Program halted. Not the value we're looking for: 3274692
# Program halted. Not the value we're looking for: 3274693
# Program halted. Not the value we're looking for: 3274694
# Program halted. Not the value we're looking for: 3274695
# Program halted. Not the value we're looking for: 3274696
# Program halted. Not the value we're looking for: 3274697
# Program halted. Not the value we're looking for: 3274698
# Program halted. Not the value we're looking for: 3274699
# Program halted. Not the value we're looking for: 3274700
# Program halted. Not the value we're looking for: 3274701
# Program halted. Not the value we're looking for: 3274702
# Program halted. Not the value we're looking for: 3274703
# Program halted. Not the value we're looking for: 3274704
# Program halted. Not the value we're looking for: 3274705
# Program halted. Not the value we're looking for: 3274706
# Program halted. Not the value we're looking for: 3274707
# Program halted. Not the value we're looking for: 3274708
# Program halted. Not the value we're looking for: 3274709
# Program halted. Not the value we're looking for: 3274710
# Program halted. Not the value we're looking for: 3274711
# Program halted. Not the value we're looking for: 3274712
# Program halted. Not the value we're looking for: 3274713
# Program halted. Not the value we're looking for: 3274714
# Program halted. Not the value we're looking for: 3274715
# Program halted. Not the value we're looking for: 3274716
# Program halted. Not the value we're looking for: 3274717
# Program halted. Not the value we're looking for: 3274718
# Program halted. Not the value we're looking for: 3274719
# Program halted. Not the value we're looking for: 3274720
# Program halted. Not the value we're looking for: 3274721
# Program halted. Not the value we're looking for: 3274722
# Program halted. Not the value we're looking for: 3274723
# Program halted. Not the value we're looking for: 3274724
# Program halted. Not the value we're looking for: 3274725
# Program halted. Not the value we're looking for: 3274726
# Program halted. Not the value we're looking for: 3274727
# Program halted. Not the value we're looking for: 3274728
# Program halted. Not the value we're looking for: 3274729
# Program halted. Not the value we're looking for: 3274730
# Program halted. Not the value we're looking for: 3274731
# Program halted. Not the value we're looking for: 3274732
# Program halted. Not the value we're looking for: 3274733
# Program halted. Not the value we're looking for: 3274734
# Program halted. Not the value we're looking for: 3274735
# Program halted. Not the value we're looking for: 3274736
# Program halted. Not the value we're looking for: 3274737
# Program halted. Not the value we're looking for: 3274738
# Program halted. Not the value we're looking for: 3274739
# Program halted. Not the value we're looking for: 3274740
# Program halted. Not the value we're looking for: 3274741
# Program halted. Not the value we're looking for: 3274742
# Program halted. Not the value we're looking for: 3274743
# Program halted. Not the value we're looking for: 3274744
# Program halted. Not the value we're looking for: 3274745
# Program halted. Not the value we're looking for: 3274746
# Program halted. Not the value we're looking for: 3274747
# Program halted. Not the value we're looking for: 3274748
# Program halted. Not the value we're looking for: 3274749
# Program halted. Not the value we're looking for: 3274750
# Program halted. Not the value we're looking for: 3274751
# Program halted. Not the value we're looking for: 3274752
# Program halted. Not the value we're looking for: 3274753
# Program halted. Not the value we're looking for: 3274754
# Program halted. Not the value we're looking for: 3274755
# Program halted. Not the value we're looking for: 3274756
# Program halted. Not the value we're looking for: 3274757
# Program halted. Not the value we're looking for: 3274758
# Program halted. Not the value we're looking for: 3274759
# Program halted. Not the value we're looking for: 3274760
# Program halted. Not the value we're looking for: 3706661
# Program halted. Not the value we're looking for: 3706662
# Program halted. Not the value we're looking for: 3706663
# Program halted. Not the value we're looking for: 3706664
# Program halted. Not the value we're looking for: 3706665
# Program halted. Not the value we're looking for: 3706666
# Program halted. Not the value we're looking for: 3706667
# Program halted. Not the value we're looking for: 3706668
# Program halted. Not the value we're looking for: 3706669
# Program halted. Not the value we're looking for: 3706670
# Program halted. Not the value we're looking for: 3706671
# Program halted. Not the value we're looking for: 3706672
# Program halted. Not the value we're looking for: 3706673
# Program halted. Not the value we're looking for: 3706674
# Program halted. Not the value we're looking for: 3706675
# Program halted. Not the value we're looking for: 3706676
# Program halted. Not the value we're looking for: 3706677
# Program halted. Not the value we're looking for: 3706678
# Program halted. Not the value we're looking for: 3706679
# Program halted. Not the value we're looking for: 3706680
# Program halted. Not the value we're looking for: 3706681
# Program halted. Not the value we're looking for: 3706682
# Program halted. Not the value we're looking for: 3706683
# Program halted. Not the value we're looking for: 3706684
# Program halted. Not the value we're looking for: 3706685
# Program halted. Not the value we're looking for: 3706686
# Program halted. Not the value we're looking for: 3706687
# Program halted. Not the value we're looking for: 3706688
# Program halted. Not the value we're looking for: 3706689
# Program halted. Not the value we're looking for: 3706690
# Program halted. Not the value we're looking for: 3706691
# Program halted. Not the value we're looking for: 3706692
# Program halted. Not the value we're looking for: 3706693
# Program halted. Not the value we're looking for: 3706694
# Program halted. Not the value we're looking for: 3706695
# Program halted. Not the value we're looking for: 3706696
# Program halted. Not the value we're looking for: 3706697
# Program halted. Not the value we're looking for: 3706698
# Program halted. Not the value we're looking for: 3706699
# Program halted. Not the value we're looking for: 3706700
# Program halted. Not the value we're looking for: 3706701
# Program halted. Not the value we're looking for: 3706702
# Program halted. Not the value we're looking for: 3706703
# Program halted. Not the value we're looking for: 3706704
# Program halted. Not the value we're looking for: 3706705
# ...
# Program halted. Not the value we're looking for: 18394746
# Program halted. Not the value we're looking for: 18394747
# Program halted. Not the value we're looking for: 18394748
# Program halted. Not the value we're looking for: 18394749
# Program halted. Not the value we're looking for: 18394750
# Program halted. Not the value we're looking for: 18394751
# Program halted. Not the value we're looking for: 18394752
# Program halted. Not the value we're looking for: 18394753
# Program halted. Not the value we're looking for: 18394754
# Program halted. Not the value we're looking for: 18394755
# Program halted. Not the value we're looking for: 18394756
# Program halted. Not the value we're looking for: 18394757
# Program halted. Not the value we're looking for: 18394758
# Program halted. Not the value we're looking for: 18394759
# Program halted. Not the value we're looking for: 18394760
# Program halted. Not the value we're looking for: 18826661
# Program halted. Not the value we're looking for: 18826662
# Program halted. Not the value we're looking for: 18826663
# Program halted. Not the value we're looking for: 18826664
# Program halted. Not the value we're looking for: 18826665
# Program halted. Not the value we're looking for: 18826666
# Program halted. Not the value we're looking for: 18826667
# Program halted. Not the value we're looking for: 18826668
# Program halted. Not the value we're looking for: 18826669
# Program halted. Not the value we're looking for: 18826670
# Program halted. Not the value we're looking for: 18826671
# Program halted. Not the value we're looking for: 18826672
# Program halted. Not the value we're looking for: 18826673
# Program halted. Not the value we're looking for: 18826674
# Program halted. Not the value we're looking for: 18826675
# Program halted. Not the value we're looking for: 18826676
# Program halted. Not the value we're looking for: 18826677
# Program halted. Not the value we're looking for: 18826678
# Program halted. Not the value we're looking for: 18826679
# Program halted. Not the value we're looking for: 18826680
# Program halted. Not the value we're looking for: 18826681
# Program halted. Not the value we're looking for: 18826682
# Program halted. Not the value we're looking for: 18826683
# Program halted. Not the value we're looking for: 18826684
# Program halted. Not the value we're looking for: 18826685
# Program halted. Not the value we're looking for: 18826686
# Program halted. Not the value we're looking for: 18826687
# Program halted. Not the value we're looking for: 18826688
# Program halted. Not the value we're looking for: 18826689
# Program halted. Not the value we're looking for: 18826690
# Program halted. Not the value we're looking for: 18826691
# Program halted. Not the value we're looking for: 18826692
# Program halted. Not the value we're looking for: 18826693
# Program halted. Not the value we're looking for: 18826694
# Program halted. Not the value we're looking for: 18826695
# Program halted. Not the value we're looking for: 18826696
# Program halted. Not the value we're looking for: 18826697
# Program halted. Not the value we're looking for: 18826698
# Program halted. Not the value we're looking for: 18826699
# Program halted. Not the value we're looking for: 18826700
# Program halted. Not the value we're looking for: 18826701
# Program halted. Not the value we're looking for: 18826702
# Program halted. Not the value we're looking for: 18826703
# Program halted. Not the value we're looking for: 18826704
# Program halted. Not the value we're looking for: 18826705
# Program halted. Not the value we're looking for: 18826706
# Program halted. Not the value we're looking for: 18826707
# Program halted. Not the value we're looking for: 18826708
# Program halted. Not the value we're looking for: 18826709
# Program halted. Not the value we're looking for: 18826710
# Program halted. Not the value we're looking for: 18826711
# Program halted. Not the value we're looking for: 18826712
# Program halted. Not the value we're looking for: 18826713
# Program halted. Not the value we're looking for: 18826714
# Program halted. Not the value we're looking for: 18826715
# Program halted. Not the value we're looking for: 18826716
# Program halted. Not the value we're looking for: 18826717
# Program halted. Not the value we're looking for: 18826718
# Program halted. Not the value we're looking for: 18826719
# Program halted. Not the value we're looking for: 18826720
# Program halted. Not the value we're looking for: 18826721
# Program halted. Not the value we're looking for: 18826722
# Program halted. Not the value we're looking for: 18826723
# Program halted. Not the value we're looking for: 18826724
# Program halted. Not the value we're looking for: 18826725
# Program halted. Not the value we're looking for: 18826726
# Program halted. Not the value we're looking for: 18826727
# Program halted. Not the value we're looking for: 18826728
# Program halted. Not the value we're looking for: 18826729
# Program halted. Not the value we're looking for: 18826730
# Program halted. Not the value we're looking for: 18826731
# Program halted. Not the value we're looking for: 18826732
# Program halted. Not the value we're looking for: 18826733
# Program halted. Not the value we're looking for: 18826734
# Program halted. Not the value we're looking for: 18826735
# Program halted. Not the value we're looking for: 18826736
# Program halted. Not the value we're looking for: 18826737
# Program halted. Not the value we're looking for: 18826738
# Program halted. Not the value we're looking for: 18826739
# Program halted. Not the value we're looking for: 18826740
# Program halted. Not the value we're looking for: 18826741
# Program halted. Not the value we're looking for: 18826742
# Program halted. Not the value we're looking for: 18826743
# Program halted. Not the value we're looking for: 18826744
# Program halted. Not the value we're looking for: 18826745
# Program halted. Not the value we're looking for: 18826746
# Program halted. Not the value we're looking for: 18826747
# Program halted. Not the value we're looking for: 18826748
# Program halted. Not the value we're looking for: 18826749
# Program halted. Not the value we're looking for: 18826750
# Program halted. Not the value we're looking for: 18826751
# Program halted. Not the value we're looking for: 18826752
# Program halted. Not the value we're looking for: 18826753
# Program halted. Not the value we're looking for: 18826754
# Program halted. Not the value we're looking for: 18826755
# Program halted. Not the value we're looking for: 18826756
# Program halted. Not the value we're looking for: 18826757
# Program halted. Not the value we're looking for: 18826758
# Program halted. Not the value we're looking for: 18826759
# Program halted. Not the value we're looking for: 18826760
# Program halted. Not the value we're looking for: 19258661
# Program halted. Not the value we're looking for: 19258662
# Program halted. Not the value we're looking for: 19258663
# Program halted. Not the value we're looking for: 19258664
# Program halted. Not the value we're looking for: 19258665
# Program halted. Not the value we're looking for: 19258666
# Program halted. Not the value we're looking for: 19258667
# Program halted. Not the value we're looking for: 19258668
# Program halted. Not the value we're looking for: 19258669
# Program halted. Not the value we're looking for: 19258670
# Program halted. Not the value we're looking for: 19258671
# Program halted. Not the value we're looking for: 19258672
# Program halted. Not the value we're looking for: 19258673
# Program halted. Not the value we're looking for: 19258674
# Program halted. Not the value we're looking for: 19258675
# Program halted. Not the value we're looking for: 19258676
# Program halted. Not the value we're looking for: 19258677
# Program halted. Not the value we're looking for: 19258678
# Program halted. Not the value we're looking for: 19258679
# Program halted. Not the value we're looking for: 19258680
# Program halted. Not the value we're looking for: 19258681
# Program halted. Not the value we're looking for: 19258682
# Program halted. Not the value we're looking for: 19258683
# Program halted. Not the value we're looking for: 19258684
# Program halted. Not the value we're looking for: 19258685
# Program halted. Not the value we're looking for: 19258686
# Program halted. Not the value we're looking for: 19258687
# Program halted. Not the value we're looking for: 19258688
# Program halted. Not the value we're looking for: 19258689
# Program halted. Not the value we're looking for: 19258690
# Program halted. Not the value we're looking for: 19258691
# Program halted. Not the value we're looking for: 19258692
# Program halted. Not the value we're looking for: 19258693
# Program halted. Not the value we're looking for: 19258694
# Program halted. Not the value we're looking for: 19258695
# Program halted. Not the value we're looking for: 19258696
# Program halted. Not the value we're looking for: 19258697
# Program halted. Not the value we're looking for: 19258698
# Program halted. Not the value we're looking for: 19258699
# Program halted. Not the value we're looking for: 19258700
# Program halted. Not the value we're looking for: 19258701
# Program halted. Not the value we're looking for: 19258702
# Program halted. Not the value we're looking for: 19258703
# Program halted. Not the value we're looking for: 19258704
# Program halted. Not the value we're looking for: 19258705
# Program halted. Not the value we're looking for: 19258706
# Program halted. Not the value we're looking for: 19258707
# Program halted. Not the value we're looking for: 19258708
# Program halted. Not the value we're looking for: 19258709
# Program halted. Not the value we're looking for: 19258710
# Program halted. Not the value we're looking for: 19258711
# Program halted. Not the value we're looking for: 19258712
# Program halted. Not the value we're looking for: 19258713
# Program halted. Not the value we're looking for: 19258714
# Program halted. Not the value we're looking for: 19258715
# Program halted. Not the value we're looking for: 19258716
# Program halted. Not the value we're looking for: 19258717
# Program halted. Not the value we're looking for: 19258718
# Program halted. Not the value we're looking for: 19258719
# Program halted. Not the value we're looking for: 19258720
# Program halted. Not the value we're looking for: 19258721
# Program halted. Not the value we're looking for: 19258722
# Program halted. Not the value we're looking for: 19258723
# Program halted. Not the value we're looking for: 19258724
# Program halted. Not the value we're looking for: 19258725
# Program halted. Not the value we're looking for: 19258726
# Program halted. Not the value we're looking for: 19258727
# Program halted. Not the value we're looking for: 19258728
# Program halted. Not the value we're looking for: 19258729
# Program halted. Not the value we're looking for: 19258730
# Program halted. Not the value we're looking for: 19258731
# Program halted. Not the value we're looking for: 19258732
# Program halted. Not the value we're looking for: 19258733
# Program halted. Not the value we're looking for: 19258734
# Program halted. Not the value we're looking for: 19258735
# Program halted. Not the value we're looking for: 19258736
# Program halted. Not the value we're looking for: 19258737
# Program halted. Not the value we're looking for: 19258738
# Program halted. Not the value we're looking for: 19258739
# Program halted. Not the value we're looking for: 19258740
# Program halted. Not the value we're looking for: 19258741
# Program halted. Not the value we're looking for: 19258742
# Program halted. Not the value we're looking for: 19258743
# Program halted. Not the value we're looking for: 19258744
# Program halted. Not the value we're looking for: 19258745
# Program halted. Not the value we're looking for: 19258746
# Program halted. Not the value we're looking for: 19258747
# Program halted. Not the value we're looking for: 19258748
# Program halted. Not the value we're looking for: 19258749
# Program halted. Not the value we're looking for: 19258750
# Program halted. Not the value we're looking for: 19258751
# Program halted. Not the value we're looking for: 19258752
# Program halted. Not the value we're looking for: 19258753
# Program halted. Not the value we're looking for: 19258754
# Program halted. Not the value we're looking for: 19258755
# Program halted. Not the value we're looking for: 19258756
# Program halted. Not the value we're looking for: 19258757
# Program halted. Not the value we're looking for: 19258758
# Program halted. Not the value we're looking for: 19258759
# Program halted. Not the value we're looking for: 19258760
# Program halted. Not the value we're looking for: 19690661
# Program halted. Not the value we're looking for: 19690662
# Program halted. Not the value we're looking for: 19690663
# Program halted. Not the value we're looking for: 19690664
# Program halted. Not the value we're looking for: 19690665
# Program halted. Not the value we're looking for: 19690666
# Program halted. Not the value we're looking for: 19690667
# Program halted. Not the value we're looking for: 19690668
# Program halted. Not the value we're looking for: 19690669
# Program halted. Not the value we're looking for: 19690670
# Program halted. Not the value we're looking for: 19690671
# Program halted. Not the value we're looking for: 19690672
# Program halted. Not the value we're looking for: 19690673
# Program halted. Not the value we're looking for: 19690674
# Program halted. Not the value we're looking for: 19690675
# Program halted. Not the value we're looking for: 19690676
# Program halted. Not the value we're looking for: 19690677
# Program halted. Not the value we're looking for: 19690678
# Program halted. Not the value we're looking for: 19690679
# Program halted. Not the value we're looking for: 19690680
# Program halted. Not the value we're looking for: 19690681
# Program halted. Not the value we're looking for: 19690682
# Program halted. Not the value we're looking for: 19690683
# Program halted. Not the value we're looking for: 19690684
# Program halted. Not the value we're looking for: 19690685
# Program halted. Not the value we're looking for: 19690686
# Program halted. Not the value we're looking for: 19690687
# Program halted. Not the value we're looking for: 19690688
# Program halted. Not the value we're looking for: 19690689
# Program halted. Not the value we're looking for: 19690690
# Program halted. Not the value we're looking for: 19690691
# Program halted. Not the value we're looking for: 19690692
# Program halted. Not the value we're looking for: 19690693
# Program halted. Not the value we're looking for: 19690694
# Program halted. Not the value we're looking for: 19690695
# Program halted. Not the value we're looking for: 19690696
# Program halted. Not the value we're looking for: 19690697
# Program halted. Not the value we're looking for: 19690698
# Program halted. Not the value we're looking for: 19690699
# Program halted. Not the value we're looking for: 19690700
# Program halted. Not the value we're looking for: 19690701
# Program halted. Not the value we're looking for: 19690702
# Program halted. Not the value we're looking for: 19690703
# Program halted. Not the value we're looking for: 19690704
# Program halted. Not the value we're looking for: 19690705
# Program halted. Not the value we're looking for: 19690706
# Program halted. Not the value we're looking for: 19690707
# Program halted. Not the value we're looking for: 19690708
# Program halted. Not the value we're looking for: 19690709
# Program halted. Not the value we're looking for: 19690710
# Program halted. Not the value we're looking for: 19690711
# Program halted. Not the value we're looking for: 19690712
# Program halted. Not the value we're looking for: 19690713
# Program halted. Not the value we're looking for: 19690714
# Program halted. Not the value we're looking for: 19690715
# Program halted. Not the value we're looking for: 19690716
# Program halted. Not the value we're looking for: 19690717
# Program halted. Not the value we're looking for: 19690718
# Program halted. Not the value we're looking for: 19690719
# Program halted. Found it! Value at position 0: 19690720
# Noun = 45. Verb = 59
